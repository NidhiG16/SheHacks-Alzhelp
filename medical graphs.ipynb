# %%
import pandas as pd
import numpy as np
import datetime
from time import strftime
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as  sns

# %%
data = pd.read_csv('sample data1.csv')

# %%
data
# Out:
#            Date Show/No show  weight  diastolic BP  systolic BP  MMSE  \
# 0    06-05-2023          yes    62.0            84          127    24
# 1    07-05-2023           no    62.0            84          127    24
# 2    08-05-2023          yes    62.0            84          127    24
# 3    09-05-2023          yes    62.3            84          126    24
# 4    10-05-2023          yes    62.2            85          127    24
# ..          ...          ...     ...           ...          ...   ...
# 362  02-05-2024          yes    54.2            90          140    15
# 363  03-05-2024          yes    54.0            90          140    15
# 364  04-05-2024          yes    54.0            90          140    15
# 365  05-05-2024          yes    54.0            90          140    15
# 366  06-05-2024          yes    54.0            90          140    15
#
#      Clinical Dementia Rate  Cholestrol
# 0                       0.5       200.4
# 1                       0.5       200.4
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    367 non-null    object
#  1   Show/No show            367 non-null    object
#  2   weight                  367 non-null    float64
#  3   diastolic BP            367 non-null    int64
#  4   systolic BP             367 non-null    int64
#  5   MMSE                    367 non-null    int64
#  6   Clinical Dementia Rate  367 non-null    float64
#  7   Cholestrol              367 non-null    float64
# dtypes: float64(3), int64(3), object(2)
# memory usage: 23.1+ KB

# %%
data['Date'] = pd.to_datetime(data['Date']).dt.date.astype('datetime64[ns]')
# Out:
# C:\Users\smrit\AppData\Local\Temp\ipykernel_19284\357863827.py:1: UserWarning: Parsing '13-05-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data['Date'] = pd.to_datetime(data['Date']).dt.date.astype('datetime64[ns]')
# C:\Users\smrit\AppData\Local\Temp\ipykernel_19284\357863827.py:1: UserWarning: Parsing '14-05-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data['Date'] = pd.to_datetime(data['Date']).dt.date.astype('datetime64[ns]')
# C:\Users\smrit\AppData\Local\Temp\ipykernel_19284\357863827.py:1: UserWarning: Parsing '15-05-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data['Date'] = pd.to_datetime(data['Date']).dt.date.astype('datetime64[ns]')
# ...

# %%
data
# Out:
#           Date Show/No show  weight  diastolic BP  systolic BP  MMSE  \
# 0   2023-06-05          yes    62.0            84          127    24
# 1   2023-07-05           no    62.0            84          127    24
# 2   2023-08-05          yes    62.0            84          127    24
# 3   2023-09-05          yes    62.3            84          126    24
# 4   2023-10-05          yes    62.2            85          127    24
# ..         ...          ...     ...           ...          ...   ...
# 362 2024-02-05          yes    54.2            90          140    15
# 363 2024-03-05          yes    54.0            90          140    15
# 364 2024-04-05          yes    54.0            90          140    15
# 365 2024-05-05          yes    54.0            90          140    15
# 366 2024-06-05          yes    54.0            90          140    15
#
#      Clinical Dementia Rate  Cholestrol
# 0                       0.5       200.4
# 1                       0.5       200.4
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    367 non-null    datetime64[ns]
#  1   Show/No show            367 non-null    object
#  2   weight                  367 non-null    float64
#  3   diastolic BP            367 non-null    int64
#  4   systolic BP             367 non-null    int64
#  5   MMSE                    367 non-null    int64
#  6   Clinical Dementia Rate  367 non-null    float64
#  7   Cholestrol              367 non-null    float64
# dtypes: datetime64[ns](1), float64(3), int64(3), object(1)
# memory usage: 23.1+ KB

# %%
data['Show/No show'].value_counts().plot(kind = 'barh', figsize=(8,6))
plt.xlabel("daily checkup", labelpad=14)
plt.ylabel("attended", labelpad=14)
plt.title("frequency of checkups attended by the patient", y=1.02);

# %%
plt.figure(figsize=(20,10))
plt.xticks(rotation=90)
df = pd.DataFrame(data)
df['Date'] = pd.to_datetime(df.Date, format='%Y-%m-%d')
d = df[df['Date'].dt.strftime('%m')=='05']
sns.barplot(d['Date'], d['weight'])
plt.show()
# Out:
# C:\Users\smrit\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.distplot(data['MMSE'])
# Out:
# C:\Users\smrit\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='MMSE', ylabel='Density'>

# %%
sns.jointplot(data['Date'], data['weight'])
# Out:
# C:\Users\smrit\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot(data['diastolic BP'], data['systolic BP'])
# Out:
# C:\Users\smrit\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.pairplot(data[['weight', 'systolic BP']])

# %%
plt.figure(figsize=(10,10))
plt.yticks(rotation = 90)
df = pd.DataFrame(data)
df['Date'] = pd.to_datetime(df.Date, format='%d-%m-%Y')
d = df[df['Date'].dt.strftime('%m-%Y')=='05-2023']

sns.stripplot(d['MMSE'], d['Date'])
plt.show()
# Out:
# C:\Users\smrit\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df = pd.read_csv('sample data1.csv', parse_dates=['Date'], index_col='Date')
df_3m = df.groupby(pd.Grouper(freq='3M')).mean()
sns.lineplot(data=df_3m, x=df_3m.index, y=data['weight'])
# Out:
# C:\Users\smrit\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '13-05-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\smrit\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '14-05-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\smrit\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '15-05-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\smrit\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '16-05-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# ...

# %%
df_grouped = df.resample('3M').sum()

plt.plot(df_grouped.index, df_grouped['weight'])
plt.xticks(rotation = 90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [85], in <cell line: 1>()
# ----> 1 df_grouped = df.resample('3M').sum()
#       3 plt.plot(df_grouped.index, df_grouped['weight'])
#       4 plt.xticks(rotation = 90)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:10541, in DataFrame.resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level, origin, offset)
#   10525 @doc(NDFrame.resample, **_shared_doc_kwargs)
#   10526 def resample(
#   10527     self,
#    (...)
#   10539     offset: TimedeltaConvertibleTypes | None = None,
#   10540 ) -> Resampler:
# > 10541     return super().resample(
#   10542         rule=rule,
#   10543         axis=axis,
#   10544         closed=closed,
#   10545         label=label,
#   10546         convention=convention,
#   10547         kind=kind,
#   10548         loffset=loffset,
# ...

# %%
df_grouped = df.resample('3M').sum()

plt.plot(df_grouped.index, df_grouped['MMSE'])
plt.xticks(rotation = 90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [83], in <cell line: 1>()
# ----> 1 df_grouped = df.resample('3M').sum()
#       3 plt.plot(df_grouped.index, df_grouped['MMSE'])
#       4 plt.xticks(rotation = 90)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:10541, in DataFrame.resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level, origin, offset)
#   10525 @doc(NDFrame.resample, **_shared_doc_kwargs)
#   10526 def resample(
#   10527     self,
#    (...)
#   10539     offset: TimedeltaConvertibleTypes | None = None,
#   10540 ) -> Resampler:
# > 10541     return super().resample(
#   10542         rule=rule,
#   10543         axis=axis,
#   10544         closed=closed,
#   10545         label=label,
#   10546         convention=convention,
#   10547         kind=kind,
#   10548         loffset=loffset,
# ...
